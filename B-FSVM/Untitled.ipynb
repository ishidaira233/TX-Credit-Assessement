# %%
import pandas as pd
from utils import scatterplot_pca
import DataDeal2
data = pd.read_csv("../Database_Encodage.csv")
X = data.drop(['Loan classification'],axis = 1)
label = data['Loan classification']
data = DataDeal2.get_data(X,label,'standardization')

# %%
data = pd.DataFrame(data)

# %%
scatterplot_pca(data=data,hue="class",pc1=3,pc2=4)
# Out:
# (<matplotlib.axes._subplots.AxesSubplot at 0x1a29afe090>,
#  PCA(copy=True, iterated_power='auto', n_components=4, random_state=None,
#      svd_solver='auto', tol=0.0, whiten=False))

# %%
data.rename(columns={27:'class'},inplace=True)
data['class'] = ['positive' if each==1 else 'negative' for each in data['class']]
